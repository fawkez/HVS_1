# %%
# imports
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
from astropy.table import Table
from astropy.table import hstack, vstack
import astropy.units as u

from isochrones.mist import MISTEvolutionTrackGrid, MISTIsochroneGrid, MIST_EvolutionTrack
# Out:
# Holoviews not imported. Some visualizations will not be available.
# /Users/mncavieres/opt/anaconda3/envs/speedytest2/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# PyMultiNest not imported.  MultiNest fits will not work.

# %%
# set up the plotting
# set font size
plt.rcParams.update({'font.size': 18})
# set the figure size
plt.rcParams.update({'figure.figsize': (10, 7)})
# set the font to latex
plt.rcParams.update({'text.usetex': True})


# set the path to save plots
plots_path = '/Users/mncavieres/Documents/2024-2/HVS/Plots/new_cmd'

# %% [markdown]
# # Using MIST isochrones to interpolate stellar parameters given age, mass and metallicity

# %%
track = MIST_EvolutionTrack()
iso_grid = MISTIsochroneGrid()

from isochrones.mist import MIST_Isochrone
from isochrones import get_ichrone
mist = get_ichrone('mist')

# %%
mass, age, feh, distance, AV = 1.0, 9.74, -0.05, 100, 0.02

# %%
# Given a mass, age, feh interpolate the isochrone grid to get the photometry of the star
#eep = mist.get_eep(mass, age,feh, accurate=True)
isochrone = iso_grid.interp([mass, age*1e9, feh])

# %%
mist = MIST_Isochrone()

pars = [353, 9.78, -1.24]  # eep, log(age), feh
mist.interp_value(pars, ['mass', 'radius', 'Teff', 'logg'])
# Out:
# array([1.16992012e-277, 1.67192852e-277, 2.67596570e-277, 3.34389781e-277])

# %%
mist.interp_mag(pars, ['K', 'BP', 'RP'])
# Out:
# (0.5131999999999864,
#  0.6519999999999835,
#  0.4624000000000179,
#  array([nan, nan, nan]))

# %%
from isochrones import get_ichrone
import numpy as np
from tqdm import tqdm

def get_star_photometry_old(feh: np.array, initial_mass: np.array, age_ejection: np.array, flight_time: np.array):
    """
    Retrieve Gaia photometry for a star given its initial mass, metallicity (feh),
    and age using the MIST isochrone model.

    Parameters:
    - feh: float, the metallicity [Fe/H] of the star.
    - initial_mass: float, the initial mass of the star in solar masses.
    - age: float, the current age of the star in Gyr.

    Returns:
    - dict with Gaia magnitudes 'G', 'BP', and 'RP' if available.
    """
    # Load the MIST isochrone model
    mist = get_ichrone('mist')

    age = age_ejection + flight_time


    # Generate the star's model with `generate`, which returns a dictionary of properties
    # Documentation Reference: https://isochrones.readthedocs.io/en/latest/usage.html#model-parameters
    try:
        star_model = mist.generate(mass=initial_mass, age=age, feh=feh, accurate=True)
    except (ValueError, RuntimeError) as e:
        print(f"Error during model generation: {e}")
        return {'G': np.nan, 'BP': np.nan, 'RP': np.nan}


            # Extract Gaia photometry (G, BP, RP) from the star model
    result = {
        'G': star_model.get('G_mag', np.nan),
        'BP': star_model.get('BP_mag', np.nan),
        'RP': star_model.get('RP_mag', np.nan),
        'Teff': star_model.get('Teff', np.nan),
        'logg': star_model.get('logg', np.nan),
        'radius': star_model.get('radius', np.nan),
        'logL': star_model.get('logL', np.nan),
        'feh': star_model.get('feh', np.nan),
        'eep': star_model.get('eep', np.nan)
    }

    return Table(result)

# Example usage
if __name__ == "__main__":
    feh = [0.25]        # Example metallicity [Fe/H]
    initial_mass = [1.0] # Example mass in solar masses
    age = [5.0]          # Example age in Gyr
    flight_time = [0.5]   

    photometry = get_star_photometry_old(feh, initial_mass, age, flight_time)
    print(f"Photometry for the star at age {age} Gyr:")
    print(f"G: {photometry['G']}, BP: {photometry['BP']}, RP: {photometry['RP']}")
# Out:
# Error during model generation: EEP minimization not successful: (np.float64(1.0), np.float64(0.5), np.float64(0.25))
# Photometry for the star at age [5.0] Gyr:
# G: nan, BP: nan, RP: nan

# %% [markdown]
# ## Function to process entire catalogs at a time

# %%
from isochrones import get_ichrone
import numpy as np
from astropy.table import Table

def get_star_photometry_v2(feh_array, initial_mass_array, age_ejection_array, flight_time_array):
    """
    Retrieve Gaia photometry for a set of stars given their initial masses, metallicities (feh),
    and ages using the MIST isochrone model.

    Parameters:
    - feh_array: array-like, metallicities [Fe/H] of the stars.
    - initial_mass_array: array-like, initial masses of the stars in solar masses.
    - age_ejection_array: array-like, ejection ages of the stars in Gyr.
    - flight_time_array: array-like, flight times of the stars in Gyr.

    Returns:
    - pandas DataFrame with Gaia magnitudes 'G', 'BP', 'RP', and other stellar properties.
    """
    # Load the MIST isochrone model
    mist = get_ichrone('mist')

    results = []

    # Iterate over each star's parameters
    for feh, initial_mass, age_ejection, flight_time in zip(
            feh_array, initial_mass_array, age_ejection_array, flight_time_array):
        
        age = np.log10((age_ejection + flight_time)) + 9 # Convert age to log10(age) in yr

        try:
            # Generate the star's model
            star_model = mist.generate(mass=initial_mass, age=age, feh=feh, accurate=True)
            
            # Extract scalar values from the DataFrame
            G_mag = star_model['G_mag'].values[0]
            BP_mag = star_model['BP_mag'].values[0]
            RP_mag = star_model['RP_mag'].values[0]
            Teff = star_model['Teff'].values[0]
            logg = star_model['logg'].values[0]
            radius = star_model['radius'].values[0]
            logL = star_model['logL'].values[0]
            feh_value = star_model['feh'].values[0]
            eep = star_model['eep'].values[0]
            
            result = {
                'G': G_mag,
                'BP': BP_mag,
                'RP': RP_mag,
                'Teff': Teff,
                'logg': logg,
                'radius': radius,
                'logL': logL,
                'feh': feh_value,
                'eep': eep
            }
        except (ValueError, RuntimeError, IndexError) as e:
            print(f"Error during model generation for star with mass {initial_mass}, "
                  f"age {age}, feh {feh}: {e}")
            # Assign NaN values if generation fails
            result = {
                'G': np.nan,
                'BP': np.nan,
                'RP': np.nan,
                'Teff': np.nan,
                'logg': np.nan,
                'radius': np.nan,
                'logL': np.nan,
                'feh': np.nan,
                'eep': np.nan
            }
        
        results.append(result)

    return Table(results)

# %%
# test on catalog
pmage_catalog = Table.read('/Users/mncavieres/Documents/2024-2/HVS/Data/SFH_sampling_catalogs/initial/sample_NSC.fits')
print(pmage_catalog.columns)
# Out:
# <TableColumns names=('mass','age','flight_time')>

# %%
pmage_catalog
# Out:
# <Table length=50000>
#        mass                age             flight_time
#      solMass               Gyr                 Gyr
#      float64             float64             float64
# ------------------ ------------------- -------------------
# 1.1873884469436904   1.906261884498922  10.849000048762402
# 1.0446552865703889   5.980805166877439   6.737128986299482
# 0.9217570624463105   3.602988606150528   9.084637282122054
# 0.8712709672798045  11.297160641440628   1.423825020928447
# 0.8444450848428964  0.8884059271939535   11.67489350806355
# 1.0048025709664057   3.185080012494407   8.842093470480648
# 0.9048905582607651 0.41811251636374974   5.343519992997313
#  0.864578082203348  11.085507256545405  1.5566699708335319
# 0.9133040526494547   4.167304884898053   7.111378080689629
#                ...                 ...                 ...
# 1.8658276038977084  1.5010197835900576   9.947593269611305
# 0.9584704228608028  1.1884715632579053  11.441152671986721
# 0.8735001425709626   8.751269503338097  3.0606200761432083
# 0.8880153067732123    7.04813150647955   4.400484104177624
# 0.8069736140528843   4.346680517973357   8.529102173422263
#  0.840743432519927    8.83647192430993  2.9401754676004086
# 0.8941690161401092  11.398478130820756 0.43573667832937524
# 0.9013380309461595  11.683654653951802  0.9623766554782385
# 0.8489677870473228  12.261916735927233  0.5687881974533495

# %% [markdown]
# # NSC synthetic photometry
#
# The masses and ages are given by sampling the SFH shown in table 3 from https://www.aanda.org/articles/aa/pdf/2020/09/aa36688-19.pdf column 2Z without young, massive stars (CWD). We now need to set the metallicity we assume for this population in order to provide reasonable photometric measurements.  Using high resolution spectroscopy https://www.aanda.org/articles/aa/pdf/2022/10/aa44411-22.pdf finds a mean metallicity of 0.29 dex for the NSC, which is what we will use here.
# See also: https://ui.adsabs.harvard.edu/abs/2017MNRAS.464..194F/abstract

# %%
feh = 0.29 # in dex from https://www.aanda.org/articles/aa/pdf/2022/10/aa44411-22.pdf 
pmage_catalog_with_photometry = hstack([pmage_catalog, get_star_photometry_v2([feh]*len(pmage_catalog), pmage_catalog['mass'], pmage_catalog['age'], pmage_catalog['flight_time'])])
# Out:
# Error during model generation for star with mass 1.1873884469436904, age 10.105689381409313, feh 0.29: EEP minimization not successful: (1.1873884469436904, 10.105689381409313, 0.29)
# Error during model generation for star with mass 2.040691421456785, age 10.072748881316034, feh 0.29: EEP minimization not successful: (2.040691421456785, 10.072748881316034, 0.29)
# Error during model generation for star with mass 1.1922086793803357, age 10.108842963347927, feh 0.29: EEP minimization not successful: (1.1922086793803357, 10.108842963347927, 0.29)
# Error during model generation for star with mass 1.66542998899955, age 10.062970348382898, feh 0.29: EEP minimization not successful: (1.66542998899955, 10.062970348382898, 0.29)
# Error during model generation for star with mass 1.1190166489041178, age 10.099529066310835, feh 0.29: EEP minimization not successful: (1.1190166489041178, 10.099529066310835, 0.29)
# Error during model generation for star with mass 1.2387913638673254, age 10.10669816707401, feh 0.29: EEP minimization not successful: (1.2387913638673254, 10.10669816707401, 0.29)
# Error during model generation for star with mass 1.0892792741627775, age 10.043239538811683, feh 0.29: EEP minimization not successful: (1.0892792741627775, 10.043239538811683, 0.29)
# Error during model generation for star with mass 1.142949738592023, age 10.060702619191286, feh 0.29: EEP minimization not successful: (1.142949738592023, 10.060702619191286, 0.29)
# Error during model generation for star with mass 1.236118408834374, age 10.086976742384337, feh 0.29: EEP minimization not successful: (1.236118408834374, 10.086976742384337, 0.29)
# Error during model generation for star with mass 1.1217015509616808, age 10.101469061750132, feh 0.29: EEP minimization not successful: (1.1217015509616808, 10.101469061750132, 0.29)
# Error during model generation for star with mass 1.1826340836523026, age 10.045172013479668, feh 0.29: EEP minimization not successful: (1.1826340836523026, 10.045172013479668, 0.29)
# Error during model generation for star with mass 1.3187055530565226, age 10.044781651587908, feh 0.29: EEP minimization not successful: (1.3187055530565226, 10.044781651587908, 0.29)
# Error during model generation for star with mass 1.2961635229459245, age 10.055656207049093, feh 0.29: EEP minimization not successful: (1.2961635229459245, 10.055656207049093, 0.29)
# Error during model generation for star with mass 1.510819407337217, age 10.061398066967802, feh 0.29: EEP minimization not successful: (1.510819407337217, 10.061398066967802, 0.29)
# Error during model generation for star with mass 1.0596780809945363, age 10.111900121078694, feh 0.29: EEP minimization not successful: (1.0596780809945363, 10.111900121078694, 0.29)
# Error during model generation for star with mass 1.3891142810477142, age 10.08557658019987, feh 0.29: EEP minimization not successful: (1.3891142810477142, 10.08557658019987, 0.29)
# Error during model generation for star with mass 1.4004395186380794, age 10.060358970188092, feh 0.29: EEP minimization not successful: (1.4004395186380794, 10.060358970188092, 0.29)
# Error during model generation for star with mass 1.2225367336885071, age 10.09774881515035, feh 0.29: EEP minimization not successful: (1.2225367336885071, 10.09774881515035, 0.29)
# Error during model generation for star with mass 1.2099148149017878, age 10.10119636018085, feh 0.29: EEP minimization not successful: (1.2099148149017878, 10.10119636018085, 0.29)
# Error during model generation for star with mass 1.9455991315575052, age 10.073502451027444, feh 0.29: EEP minimization not successful: (1.9455991315575052, 10.073502451027444, 0.29)
# Error during model generation for star with mass 1.1665569419739752, age 10.046846945283272, feh 0.29: EEP minimization not successful: (1.1665569419739752, 10.046846945283272, 0.29)
# Error during model generation for star with mass 1.405071911862831, age 10.061852503601747, feh 0.29: EEP minimization not successful: (1.405071911862831, 10.061852503601747, 0.29)
# Error during model generation for star with mass 1.1540535012204063, age 10.110089173680725, feh 0.29: EEP minimization not successful: (1.1540535012204063, 10.110089173680725, 0.29)
# Error during model generation for star with mass 1.2630012473093626, age 10.086474066705435, feh 0.29: EEP minimization not successful: (1.2630012473093626, 10.086474066705435, 0.29)
# Error during model generation for star with mass 1.5117396657567306, age 10.10775312947174, feh 0.29: EEP minimization not successful: (1.5117396657567306, 10.10775312947174, 0.29)
# Error during model generation for star with mass 1.0921341080984919, age 10.107275309093474, feh 0.29: EEP minimization not successful: (1.0921341080984919, 10.107275309093474, 0.29)
# Error during model generation for star with mass 2.15468465773509, age 10.101893541581685, feh 0.29: EEP minimization not successful: (2.15468465773509, 10.101893541581685, 0.29)
# Error during model generation for star with mass 1.2141586501112225, age 10.08862504738863, feh 0.29: EEP minimization not successful: (1.2141586501112225, 10.08862504738863, 0.29)
# Error during model generation for star with mass 1.1177343511951225, age 10.099864152766115, feh 0.29: EEP minimization not successful: (1.1177343511951225, 10.099864152766115, 0.29)
# Error during model generation for star with mass 1.340298119074052, age 10.040583332614073, feh 0.29: EEP minimization not successful: (1.340298119074052, 10.040583332614073, 0.29)
# Error during model generation for star with mass 1.1077695781702794, age 10.076662284235049, feh 0.29: EEP minimization not successful: (1.1077695781702794, 10.076662284235049, 0.29)
# Error during model generation for star with mass 1.3171178631930323, age 10.065120520915448, feh 0.29: EEP minimization not successful: (1.3171178631930323, 10.065120520915448, 0.29)
# Error during model generation for star with mass 1.23187869978064, age 10.07993487101941, feh 0.29: EEP minimization not successful: (1.23187869978064, 10.07993487101941, 0.29)
# Error during model generation for star with mass 1.093238607943293, age 10.095776733945767, feh 0.29: EEP minimization not successful: (1.093238607943293, 10.095776733945767, 0.29)
# Error during model generation for star with mass 1.4867446981436976, age 10.070144260059582, feh 0.29: EEP minimization not successful: (1.4867446981436976, 10.070144260059582, 0.29)
# Error during model generation for star with mass 1.1471643169273347, age 10.10798059236677, feh 0.29: EEP minimization not successful: (1.1471643169273347, 10.10798059236677, 0.29)
# Error during model generation for star with mass 1.897195224956444, age 10.072388007508682, feh 0.29: EEP minimization not successful: (1.897195224956444, 10.072388007508682, 0.29)
# Error during model generation for star with mass 2.166898086267805, age 10.110922248305103, feh 0.29: EEP minimization not successful: (2.166898086267805, 10.110922248305103, 0.29)
# Error during model generation for star with mass 1.3518794398100862, age 10.072416119905167, feh 0.29: EEP minimization not successful: (1.3518794398100862, 10.072416119905167, 0.29)
# Error during model generation for star with mass 1.0932841977789638, age 10.092020077524932, feh 0.29: EEP minimization not successful: (1.0932841977789638, 10.092020077524932, 0.29)
# Error during model generation for star with mass 1.2665693919960483, age 10.046853928408888, feh 0.29: EEP minimization not successful: (1.2665693919960483, 10.046853928408888, 0.29)
# Error during model generation for star with mass 1.2241310614589163, age 10.059915794055348, feh 0.29: EEP minimization not successful: (1.2241310614589163, 10.059915794055348, 0.29)
# Error during model generation for star with mass 1.1575930698088068, age 10.041551167345183, feh 0.29: EEP minimization not successful: (1.1575930698088068, 10.041551167345183, 0.29)
# Error during model generation for star with mass 1.1841655825498982, age 10.103576992443053, feh 0.29: EEP minimization not successful: (1.1841655825498982, 10.103576992443053, 0.29)
# Error during model generation for star with mass 1.263139026663773, age 10.059901431950202, feh 0.29: EEP minimization not successful: (1.263139026663773, 10.059901431950202, 0.29)
# Error during model generation for star with mass 1.2549431998101246, age 10.090011424998238, feh 0.29: EEP minimization not successful: (1.2549431998101246, 10.090011424998238, 0.29)
# Error during model generation for star with mass 1.2973590777423054, age 10.044507065488029, feh 0.29: EEP minimization not successful: (1.2973590777423054, 10.044507065488029, 0.29)
# Error during model generation for star with mass 1.3594894633894639, age 9.714726200797385, feh 0.29: EEP minimization not successful: (1.3594894633894639, 9.714726200797385, 0.29)
# Error during model generation for star with mass 1.3115579848760275, age 10.10388394141009, feh 0.29: EEP minimization not successful: (1.3115579848760275, 10.10388394141009, 0.29)
# Error during model generation for star with mass 1.0998117451495346, age 10.082009303881573, feh 0.29: EEP minimization not successful: (1.0998117451495346, 10.082009303881573, 0.29)
# Error during model generation for star with mass 1.1821707281783844, age 10.062966743475425, feh 0.29: EEP minimization not successful: (1.1821707281783844, 10.062966743475425, 0.29)
# Error during model generation for star with mass 1.2201213254472314, age 10.042989061043823, feh 0.29: EEP minimization not successful: (1.2201213254472314, 10.042989061043823, 0.29)
# Error during model generation for star with mass 1.2412326171242842, age 10.108261529033276, feh 0.29: EEP minimization not successful: (1.2412326171242842, 10.108261529033276, 0.29)
# Error during model generation for star with mass 1.3599917722759038, age 10.055824785084342, feh 0.29: EEP minimization not successful: (1.3599917722759038, 10.055824785084342, 0.29)
# Error during model generation for star with mass 1.0608800959058613, age 10.092507108411601, feh 0.29: EEP minimization not successful: (1.0608800959058613, 10.092507108411601, 0.29)
# Error during model generation for star with mass 1.134295957888177, age 10.046043185416305, feh 0.29: EEP minimization not successful: (1.134295957888177, 10.046043185416305, 0.29)
# Error during model generation for star with mass 1.7013970508361556, age 10.074437655002212, feh 0.29: EEP minimization not successful: (1.7013970508361556, 10.074437655002212, 0.29)
# Error during model generation for star with mass 1.104023851130175, age 10.087758760364903, feh 0.29: EEP minimization not successful: (1.104023851130175, 10.087758760364903, 0.29)
# Error during model generation for star with mass 1.1816007446003582, age 10.074993218457077, feh 0.29: EEP minimization not successful: (1.1816007446003582, 10.074993218457077, 0.29)
# Error during model generation for star with mass 1.0567752525855754, age 10.0933352509897, feh 0.29: EEP minimization not successful: (1.0567752525855754, 10.0933352509897, 0.29)
# Error during model generation for star with mass 1.1188099022065834, age 10.077081629084159, feh 0.29: EEP minimization not successful: (1.1188099022065834, 10.077081629084159, 0.29)
# Error during model generation for star with mass 1.802161838352094, age 9.378009696403874, feh 0.29: EEP minimization not successful: (1.802161838352094, 9.378009696403874, 0.29)
# Error during model generation for star with mass 1.2069096474551755, age 10.061003510856853, feh 0.29: EEP minimization not successful: (1.2069096474551755, 10.061003510856853, 0.29)
# Error during model generation for star with mass 1.3544814597596975, age 10.099790706259405, feh 0.29: EEP minimization not successful: (1.3544814597596975, 10.099790706259405, 0.29)
# Error during model generation for star with mass 1.1105346323897285, age 10.050280078681103, feh 0.29: EEP minimization not successful: (1.1105346323897285, 10.050280078681103, 0.29)
# Error during model generation for star with mass 1.1685810162459889, age 10.081091320437155, feh 0.29: EEP minimization not successful: (1.1685810162459889, 10.081091320437155, 0.29)
# Error during model generation for star with mass 1.0986418795088166, age 10.107519426462542, feh 0.29: EEP minimization not successful: (1.0986418795088166, 10.107519426462542, 0.29)
# Error during model generation for star with mass 1.4035814089087506, age 10.076570515671316, feh 0.29: EEP minimization not successful: (1.4035814089087506, 10.076570515671316, 0.29)
# Error during model generation for star with mass 1.7937879046069882, age 10.104328570031981, feh 0.29: EEP minimization not successful: (1.7937879046069882, 10.104328570031981, 0.29)
# Error during model generation for star with mass 2.458321466727889, age 9.39773399264921, feh 0.29: EEP minimization not successful: (2.458321466727889, 9.39773399264921, 0.29)
# Error during model generation for star with mass 1.3918020477060231, age 10.053406524536593, feh 0.29: EEP minimization not successful: (1.3918020477060231, 10.053406524536593, 0.29)
# Error during model generation for star with mass 1.7552572294581348, age 10.098758968432138, feh 0.29: EEP minimization not successful: (1.7552572294581348, 10.098758968432138, 0.29)
# Error during model generation for star with mass 1.2944019088299519, age 10.107751421812958, feh 0.29: EEP minimization not successful: (1.2944019088299519, 10.107751421812958, 0.29)
# Error during model generation for star with mass 1.124717772718441, age 10.050695555802378, feh 0.29: EEP minimization not successful: (1.124717772718441, 10.050695555802378, 0.29)
# Error during model generation for star with mass 1.0855152295148218, age 10.083483855169055, feh 0.29: EEP minimization not successful: (1.0855152295148218, 10.083483855169055, 0.29)
# Error during model generation for star with mass 2.104790543117509, age 10.107121287062125, feh 0.29: EEP minimization not successful: (2.104790543117509, 10.107121287062125, 0.29)
# Error during model generation for star with mass 1.6094180417898438, age 10.05332063578955, feh 0.29: EEP minimization not successful: (1.6094180417898438, 10.05332063578955, 0.29)
# Error during model generation for star with mass 1.1099341059115568, age 10.04475190107006, feh 0.29: EEP minimization not successful: (1.1099341059115568, 10.04475190107006, 0.29)
# Error during model generation for star with mass 1.2184221988960753, age 10.097017643787924, feh 0.29: EEP minimization not successful: (1.2184221988960753, 10.097017643787924, 0.29)
# Error during model generation for star with mass 1.0635483839190805, age 10.098510138808452, feh 0.29: EEP minimization not successful: (1.0635483839190805, 10.098510138808452, 0.29)
# Error during model generation for star with mass 1.184568478533089, age 10.108256743619323, feh 0.29: EEP minimization not successful: (1.184568478533089, 10.108256743619323, 0.29)
# Error during model generation for star with mass 2.666782323580026, age 10.091555528059768, feh 0.29: EEP minimization not successful: (2.666782323580026, 10.091555528059768, 0.29)
# Error during model generation for star with mass 1.1143969304501662, age 10.04239094588118, feh 0.29: EEP minimization not successful: (1.1143969304501662, 10.04239094588118, 0.29)
# Error during model generation for star with mass 1.3193295998568726, age 10.090494865201546, feh 0.29: EEP minimization not successful: (1.3193295998568726, 10.090494865201546, 0.29)
# Error during model generation for star with mass 1.2596207267635524, age 10.039446612936356, feh 0.29: EEP minimization not successful: (1.2596207267635524, 10.039446612936356, 0.29)
# Error during model generation for star with mass 1.1785030986908385, age 10.044050260706902, feh 0.29: EEP minimization not successful: (1.1785030986908385, 10.044050260706902, 0.29)
# Error during model generation for star with mass 1.2385303604047624, age 10.111585070067115, feh 0.29: EEP minimization not successful: (1.2385303604047624, 10.111585070067115, 0.29)
# Error during model generation for star with mass 1.2377620623672023, age 10.073327386125547, feh 0.29: EEP minimization not successful: (1.2377620623672023, 10.073327386125547, 0.29)
# Error during model generation for star with mass 1.1883417376206353, age 10.093660588207662, feh 0.29: EEP minimization not successful: (1.1883417376206353, 10.093660588207662, 0.29)
# Error during model generation for star with mass 1.0978572224916845, age 10.107013220098107, feh 0.29: EEP minimization not successful: (1.0978572224916845, 10.107013220098107, 0.29)
# Error during model generation for star with mass 1.6678074206880327, age 10.079464730288839, feh 0.29: EEP minimization not successful: (1.6678074206880327, 10.079464730288839, 0.29)
# Error during model generation for star with mass 1.07256556363108, age 10.109471455411109, feh 0.29: EEP minimization not successful: (1.07256556363108, 10.109471455411109, 0.29)
# Error during model generation for star with mass 2.707333795712745, age 9.385354235831295, feh 0.29: EEP minimization not successful: (2.707333795712745, 9.385354235831295, 0.29)
# Error during model generation for star with mass 1.135791604973691, age 10.10389184488237, feh 0.29: EEP minimization not successful: (1.135791604973691, 10.10389184488237, 0.29)
# Error during model generation for star with mass 1.2609603188246512, age 10.073740761496955, feh 0.29: EEP minimization not successful: (1.2609603188246512, 10.073740761496955, 0.29)
# Error during model generation for star with mass 1.1494199915863847, age 10.056879480537825, feh 0.29: EEP minimization not successful: (1.1494199915863847, 10.056879480537825, 0.29)
# Error during model generation for star with mass 1.097911788884532, age 10.111576360961612, feh 0.29: EEP minimization not successful: (1.097911788884532, 10.111576360961612, 0.29)
# Error during model generation for star with mass 1.301790585647268, age 10.079020231010578, feh 0.29: EEP minimization not successful: (1.301790585647268, 10.079020231010578, 0.29)
# Error during model generation for star with mass 1.32557644332196, age 10.070646652737578, feh 0.29: EEP minimization not successful: (1.32557644332196, 10.070646652737578, 0.29)
# Error during model generation for star with mass 1.3580399551731317, age 10.046907066681243, feh 0.29: EEP minimization not successful: (1.3580399551731317, 10.046907066681243, 0.29)
# Error during model generation for star with mass 1.5893872838754957, age 10.046731199262828, feh 0.29: EEP minimization not successful: (1.5893872838754957, 10.046731199262828, 0.29)
# Error during model generation for star with mass 1.080693426431331, age 10.089762481286728, feh 0.29: EEP minimization not successful: (1.080693426431331, 10.089762481286728, 0.29)
# Error during model generation for star with mass 1.0929672879196808, age 10.109050531051302, feh 0.29: EEP minimization not successful: (1.0929672879196808, 10.109050531051302, 0.29)
# Error during model generation for star with mass 1.5398946504559075, age 10.07565064821121, feh 0.29: EEP minimization not successful: (1.5398946504559075, 10.07565064821121, 0.29)
# Error during model generation for star with mass 1.6127239547572796, age 10.058780316884034, feh 0.29: EEP minimization not successful: (1.6127239547572796, 10.058780316884034, 0.29)
# Error during model generation for star with mass 1.4399540226775611, age 10.045146121319712, feh 0.29: EEP minimization not successful: (1.4399540226775611, 10.045146121319712, 0.29)
# Error during model generation for star with mass 1.3057894649473152, age 10.086280647086554, feh 0.29: EEP minimization not successful: (1.3057894649473152, 10.086280647086554, 0.29)
# Error during model generation for star with mass 1.0937060649409032, age 10.086563120011533, feh 0.29: EEP minimization not successful: (1.0937060649409032, 10.086563120011533, 0.29)
# Error during model generation for star with mass 1.146547070650867, age 10.056372752441186, feh 0.29: EEP minimization not successful: (1.146547070650867, 10.056372752441186, 0.29)
# Error during model generation for star with mass 1.6378636805515363, age 10.105426784781269, feh 0.29: EEP minimization not successful: (1.6378636805515363, 10.105426784781269, 0.29)
# Error during model generation for star with mass 1.194563585320843, age 10.041712794168967, feh 0.29: EEP minimization not successful: (1.194563585320843, 10.041712794168967, 0.29)
# Error during model generation for star with mass 1.2082829039114167, age 10.070718102750016, feh 0.29: EEP minimization not successful: (1.2082829039114167, 10.070718102750016, 0.29)
# Error during model generation for star with mass 1.4098805620435435, age 10.094218848631833, feh 0.29: EEP minimization not successful: (1.4098805620435435, 10.094218848631833, 0.29)
# Error during model generation for star with mass 1.14382502696327, age 10.097420706075505, feh 0.29: EEP minimization not successful: (1.14382502696327, 10.097420706075505, 0.29)
# Error during model generation for star with mass 1.2649368372218908, age 10.109439649157746, feh 0.29: EEP minimization not successful: (1.2649368372218908, 10.109439649157746, 0.29)
# Error during model generation for star with mass 1.0940772627740114, age 10.110868941938078, feh 0.29: EEP minimization not successful: (1.0940772627740114, 10.110868941938078, 0.29)
# Error during model generation for star with mass 1.2455710155813198, age 10.102553161432963, feh 0.29: EEP minimization not successful: (1.2455710155813198, 10.102553161432963, 0.29)
# Error during model generation for star with mass 1.6799550545806659, age 10.104519194810798, feh 0.29: EEP minimization not successful: (1.6799550545806659, 10.104519194810798, 0.29)
# Error during model generation for star with mass 1.3025541578689313, age 10.08417930987453, feh 0.29: EEP minimization not successful: (1.3025541578689313, 10.08417930987453, 0.29)
# Error during model generation for star with mass 1.4354254724108153, age 10.102799257126478, feh 0.29: EEP minimization not successful: (1.4354254724108153, 10.102799257126478, 0.29)
# Error during model generation for star with mass 1.1179629329258112, age 10.06503490345037, feh 0.29: EEP minimization not successful: (1.1179629329258112, 10.06503490345037, 0.29)
# Error during model generation for star with mass 1.190372191079713, age 10.055473456596875, feh 0.29: EEP minimization not successful: (1.190372191079713, 10.055473456596875, 0.29)
# Error during model generation for star with mass 1.1165704909529437, age 10.079093372829256, feh 0.29: EEP minimization not successful: (1.1165704909529437, 10.079093372829256, 0.29)
# Error during model generation for star with mass 1.1262949022515432, age 10.044286959749112, feh 0.29: EEP minimization not successful: (1.1262949022515432, 10.044286959749112, 0.29)
# Error during model generation for star with mass 1.1708068456947653, age 10.08906119015411, feh 0.29: EEP minimization not successful: (1.1708068456947653, 10.08906119015411, 0.29)
# Error during model generation for star with mass 1.1084526545677884, age 10.10494339150402, feh 0.29: EEP minimization not successful: (1.1084526545677884, 10.10494339150402, 0.29)
# Error during model generation for star with mass 1.142543325498664, age 10.05166423078676, feh 0.29: EEP minimization not successful: (1.142543325498664, 10.05166423078676, 0.29)
# Error during model generation for star with mass 1.2069282548034048, age 10.08338761364488, feh 0.29: EEP minimization not successful: (1.2069282548034048, 10.08338761364488, 0.29)
# Error during model generation for star with mass 1.0838329699760385, age 10.08565787562447, feh 0.29: EEP minimization not successful: (1.0838329699760385, 10.08565787562447, 0.29)
# Error during model generation for star with mass 1.1690265298797693, age 10.069806758520066, feh 0.29: EEP minimization not successful: (1.1690265298797693, 10.069806758520066, 0.29)
# Error during model generation for star with mass 1.1008590864091938, age 10.112197102237067, feh 0.29: EEP minimization not successful: (1.1008590864091938, 10.112197102237067, 0.29)
# Error during model generation for star with mass 1.142454409337919, age 10.053997776138829, feh 0.29: EEP minimization not successful: (1.142454409337919, 10.053997776138829, 0.29)
# Error during model generation for star with mass 1.3558286517494353, age 10.090244038312688, feh 0.29: EEP minimization not successful: (1.3558286517494353, 10.090244038312688, 0.29)
# Error during model generation for star with mass 1.0647043275831611, age 10.086718025022046, feh 0.29: EEP minimization not successful: (1.0647043275831611, 10.086718025022046, 0.29)
# Error during model generation for star with mass 1.1087144558939876, age 10.08554924017964, feh 0.29: EEP minimization not successful: (1.1087144558939876, 10.08554924017964, 0.29)
# Error during model generation for star with mass 1.111219366853745, age 10.077531845356653, feh 0.29: EEP minimization not successful: (1.111219366853745, 10.077531845356653, 0.29)
# Error during model generation for star with mass 1.3573068268205395, age 9.715647906014956, feh 0.29: EEP minimization not successful: (1.3573068268205395, 9.715647906014956, 0.29)
# Error during model generation for star with mass 1.1115448157928385, age 10.058635811940434, feh 0.29: EEP minimization not successful: (1.1115448157928385, 10.058635811940434, 0.29)
# Error during model generation for star with mass 1.2096227601606029, age 10.060579949836118, feh 0.29: EEP minimization not successful: (1.2096227601606029, 10.060579949836118, 0.29)
# Error during model generation for star with mass 1.2895963040037501, age 10.048211032411022, feh 0.29: EEP minimization not successful: (1.2895963040037501, 10.048211032411022, 0.29)
# Error during model generation for star with mass 1.1285350525167797, age 10.089135258825983, feh 0.29: EEP minimization not successful: (1.1285350525167797, 10.089135258825983, 0.29)
# Error during model generation for star with mass 1.5044473002078331, age 10.043177465340417, feh 0.29: EEP minimization not successful: (1.5044473002078331, 10.043177465340417, 0.29)
# Error during model generation for star with mass 1.1529940515706856, age 10.068237692685845, feh 0.29: EEP minimization not successful: (1.1529940515706856, 10.068237692685845, 0.29)
# Error during model generation for star with mass 1.1976803633077924, age 10.104414998065524, feh 0.29: EEP minimization not successful: (1.1976803633077924, 10.104414998065524, 0.29)
# Error during model generation for star with mass 1.218896233467591, age 10.0632368794139, feh 0.29: EEP minimization not successful: (1.218896233467591, 10.0632368794139, 0.29)
# Error during model generation for star with mass 1.1506043189095272, age 10.069782361380138, feh 0.29: EEP minimization not successful: (1.1506043189095272, 10.069782361380138, 0.29)
# Error during model generation for star with mass 1.1136115036338283, age 10.07050819008961, feh 0.29: EEP minimization not successful: (1.1136115036338283, 10.07050819008961, 0.29)
# Error during model generation for star with mass 1.1269183279654948, age 10.066314891361344, feh 0.29: EEP minimization not successful: (1.1269183279654948, 10.066314891361344, 0.29)
# Error during model generation for star with mass 1.422731143241121, age 10.109756763859464, feh 0.29: EEP minimization not successful: (1.422731143241121, 10.109756763859464, 0.29)
# Error during model generation for star with mass 1.1652173952402576, age 10.089494595448782, feh 0.29: EEP minimization not successful: (1.1652173952402576, 10.089494595448782, 0.29)
# Error during model generation for star with mass 1.5741505287022968, age 10.0596797039654, feh 0.29: EEP minimization not successful: (1.5741505287022968, 10.0596797039654, 0.29)
# Error during model generation for star with mass 1.073756610409619, age 10.089937291196232, feh 0.29: EEP minimization not successful: (1.073756610409619, 10.089937291196232, 0.29)
# Error during model generation for star with mass 1.1689201919245369, age 10.04318663011652, feh 0.29: EEP minimization not successful: (1.1689201919245369, 10.04318663011652, 0.29)
# Error during model generation for star with mass 1.0887607412101787, age 10.098519418337832, feh 0.29: EEP minimization not successful: (1.0887607412101787, 10.098519418337832, 0.29)
# Error during model generation for star with mass 1.1954104726439172, age 10.106488120501467, feh 0.29: EEP minimization not successful: (1.1954104726439172, 10.106488120501467, 0.29)
# Error during model generation for star with mass 1.0936898134656752, age 10.04969589515984, feh 0.29: EEP minimization not successful: (1.0936898134656752, 10.04969589515984, 0.29)
# Error during model generation for star with mass 1.222368263555964, age 10.058278195221153, feh 0.29: EEP minimization not successful: (1.222368263555964, 10.058278195221153, 0.29)
# Error during model generation for star with mass 1.2364826406744143, age 10.070051907376397, feh 0.29: EEP minimization not successful: (1.2364826406744143, 10.070051907376397, 0.29)
# Error during model generation for star with mass 1.3934600055804764, age 10.104427493970903, feh 0.29: EEP minimization not successful: (1.3934600055804764, 10.104427493970903, 0.29)
# Error during model generation for star with mass 1.2112855482917386, age 10.052241335993008, feh 0.29: EEP minimization not successful: (1.2112855482917386, 10.052241335993008, 0.29)
# Error during model generation for star with mass 1.405783649514954, age 10.084407798278376, feh 0.29: EEP minimization not successful: (1.405783649514954, 10.084407798278376, 0.29)
# Error during model generation for star with mass 1.1134516521145466, age 10.056642092128437, feh 0.29: EEP minimization not successful: (1.1134516521145466, 10.056642092128437, 0.29)
# Error during model generation for star with mass 1.6239665297186154, age 10.096885903297355, feh 0.29: EEP minimization not successful: (1.6239665297186154, 10.096885903297355, 0.29)
# Error during model generation for star with mass 1.0822640081948487, age 10.096120923259353, feh 0.29: EEP minimization not successful: (1.0822640081948487, 10.096120923259353, 0.29)
# Error during model generation for star with mass 1.0869655586980085, age 10.109254308215286, feh 0.29: EEP minimization not successful: (1.0869655586980085, 10.109254308215286, 0.29)
# Error during model generation for star with mass 1.1292706489694957, age 10.063581749486241, feh 0.29: EEP minimization not successful: (1.1292706489694957, 10.063581749486241, 0.29)
# Error during model generation for star with mass 1.3446419919021557, age 10.073773031342125, feh 0.29: EEP minimization not successful: (1.3446419919021557, 10.073773031342125, 0.29)
# Error during model generation for star with mass 1.0918290547847083, age 10.102596154613089, feh 0.29: EEP minimization not successful: (1.0918290547847083, 10.102596154613089, 0.29)
# Error during model generation for star with mass 1.4254114942165244, age 10.098340927491641, feh 0.29: EEP minimization not successful: (1.4254114942165244, 10.098340927491641, 0.29)
# Error during model generation for star with mass 1.1960560511673028, age 10.059794308434453, feh 0.29: EEP minimization not successful: (1.1960560511673028, 10.059794308434453, 0.29)
# Error during model generation for star with mass 1.1085955298021255, age 10.050837233368805, feh 0.29: EEP minimization not successful: (1.1085955298021255, 10.050837233368805, 0.29)
# Error during model generation for star with mass 1.4629147833051674, age 10.042241670226165, feh 0.29: EEP minimization not successful: (1.4629147833051674, 10.042241670226165, 0.29)
# Error during model generation for star with mass 1.0864570995633696, age 10.054058857149027, feh 0.29: EEP minimization not successful: (1.0864570995633696, 10.054058857149027, 0.29)
# Error during model generation for star with mass 1.119224622632108, age 10.072384808567627, feh 0.29: EEP minimization not successful: (1.119224622632108, 10.072384808567627, 0.29)
# Error during model generation for star with mass 1.0546692622576992, age 10.094223867060203, feh 0.29: EEP minimization not successful: (1.0546692622576992, 10.094223867060203, 0.29)
# Error during model generation for star with mass 1.1551152413177208, age 10.085101335449686, feh 0.29: EEP minimization not successful: (1.1551152413177208, 10.085101335449686, 0.29)
# Error during model generation for star with mass 1.5266416260638298, age 9.726416431604196, feh 0.29: EEP minimization not successful: (1.5266416260638298, 9.726416431604196, 0.29)
# Error during model generation for star with mass 1.9365295218382708, age 10.089188734822102, feh 0.29: EEP minimization not successful: (1.9365295218382708, 10.089188734822102, 0.29)
# Error during model generation for star with mass 1.2157356565445636, age 10.085030502979928, feh 0.29: EEP minimization not successful: (1.2157356565445636, 10.085030502979928, 0.29)
# Error during model generation for star with mass 1.4151100087397714, age 10.095493041449426, feh 0.29: EEP minimization not successful: (1.4151100087397714, 10.095493041449426, 0.29)
# Error during model generation for star with mass 1.1650787772632871, age 10.055029620444897, feh 0.29: EEP minimization not successful: (1.1650787772632871, 10.055029620444897, 0.29)
# Error during model generation for star with mass 1.2608123034251513, age 10.059262496060231, feh 0.29: EEP minimization not successful: (1.2608123034251513, 10.059262496060231, 0.29)
# Error during model generation for star with mass 1.2674565651277294, age 10.056074814672419, feh 0.29: EEP minimization not successful: (1.2674565651277294, 10.056074814672419, 0.29)
# Error during model generation for star with mass 1.3288040750413386, age 10.046309086363204, feh 0.29: EEP minimization not successful: (1.3288040750413386, 10.046309086363204, 0.29)
# Error during model generation for star with mass 1.1715394469552138, age 10.105175517372583, feh 0.29: EEP minimization not successful: (1.1715394469552138, 10.105175517372583, 0.29)
# Error during model generation for star with mass 1.2894688421042224, age 10.105126249185682, feh 0.29: EEP minimization not successful: (1.2894688421042224, 10.105126249185682, 0.29)
# Error during model generation for star with mass 1.1650679346027897, age 10.054189968697866, feh 0.29: EEP minimization not successful: (1.1650679346027897, 10.054189968697866, 0.29)
# Error during model generation for star with mass 1.1967705251822414, age 10.11349607758134, feh 0.29: EEP minimization not successful: (1.1967705251822414, 10.11349607758134, 0.29)
# Error during model generation for star with mass 1.1234321436766943, age 10.101140107190016, feh 0.29: EEP minimization not successful: (1.1234321436766943, 10.101140107190016, 0.29)
# Error during model generation for star with mass 1.3529628774977964, age 10.071482949268006, feh 0.29: EEP minimization not successful: (1.3529628774977964, 10.071482949268006, 0.29)
# Error during model generation for star with mass 1.0979121955086903, age 10.058545269525839, feh 0.29: EEP minimization not successful: (1.0979121955086903, 10.058545269525839, 0.29)
# Error during model generation for star with mass 1.2893820807164031, age 10.071160723460002, feh 0.29: EEP minimization not successful: (1.2893820807164031, 10.071160723460002, 0.29)
# Error during model generation for star with mass 1.0757556507696013, age 10.070690050619048, feh 0.29: EEP minimization not successful: (1.0757556507696013, 10.070690050619048, 0.29)
# Error during model generation for star with mass 2.175354455825634, age 10.056432082111952, feh 0.29: EEP minimization not successful: (2.175354455825634, 10.056432082111952, 0.29)
# Error during model generation for star with mass 1.0474285271166488, age 10.107389909803398, feh 0.29: EEP minimization not successful: (1.0474285271166488, 10.107389909803398, 0.29)
# Error during model generation for star with mass 1.0876364112639985, age 10.046047456717043, feh 0.29: EEP minimization not successful: (1.0876364112639985, 10.046047456717043, 0.29)
# Error during model generation for star with mass 1.1014102347544419, age 10.055864208156606, feh 0.29: EEP minimization not successful: (1.1014102347544419, 10.055864208156606, 0.29)
# Error during model generation for star with mass 1.1587710517207443, age 10.06931461563772, feh 0.29: EEP minimization not successful: (1.1587710517207443, 10.06931461563772, 0.29)
# Error during model generation for star with mass 1.1125378317471974, age 10.063449434041367, feh 0.29: EEP minimization not successful: (1.1125378317471974, 10.063449434041367, 0.29)
# Error during model generation for star with mass 1.1555124918935515, age 10.060839299684433, feh 0.29: EEP minimization not successful: (1.1555124918935515, 10.060839299684433, 0.29)
# Error during model generation for star with mass 1.1654288851051624, age 10.10154480367894, feh 0.29: EEP minimization not successful: (1.1654288851051624, 10.10154480367894, 0.29)
# Error during model generation for star with mass 1.1659312281060734, age 10.04625338839481, feh 0.29: EEP minimization not successful: (1.1659312281060734, 10.04625338839481, 0.29)
# Error during model generation for star with mass 1.578229189789905, age 10.11284691970104, feh 0.29: EEP minimization not successful: (1.578229189789905, 10.11284691970104, 0.29)
# Error during model generation for star with mass 1.2318754457611805, age 10.11353139062605, feh 0.29: EEP minimization not successful: (1.2318754457611805, 10.11353139062605, 0.29)
# Error during model generation for star with mass 1.2854003928903734, age 10.047534788512252, feh 0.29: EEP minimization not successful: (1.2854003928903734, 10.047534788512252, 0.29)
# Error during model generation for star with mass 1.283514086105328, age 10.084571662417313, feh 0.29: EEP minimization not successful: (1.283514086105328, 10.084571662417313, 0.29)
# Error during model generation for star with mass 1.400131230593222, age 9.729447122006336, feh 0.29: EEP minimization not successful: (1.400131230593222, 9.729447122006336, 0.29)
# Error during model generation for star with mass 1.263645882032618, age 10.09044385802327, feh 0.29: EEP minimization not successful: (1.263645882032618, 10.09044385802327, 0.29)
# Error during model generation for star with mass 1.111427029189916, age 10.07835981230668, feh 0.29: EEP minimization not successful: (1.111427029189916, 10.07835981230668, 0.29)
# Error during model generation for star with mass 1.2413459246900727, age 10.066457149714847, feh 0.29: EEP minimization not successful: (1.2413459246900727, 10.066457149714847, 0.29)
# Error during model generation for star with mass 1.28494046796224, age 10.080133423925691, feh 0.29: EEP minimization not successful: (1.28494046796224, 10.080133423925691, 0.29)
# Error during model generation for star with mass 1.2024343124122014, age 10.041714738029299, feh 0.29: EEP minimization not successful: (1.2024343124122014, 10.041714738029299, 0.29)
# Error during model generation for star with mass 1.087193187684983, age 10.05710803654856, feh 0.29: EEP minimization not successful: (1.087193187684983, 10.05710803654856, 0.29)
# Error during model generation for star with mass 1.1405390676012483, age 10.043276576723297, feh 0.29: EEP minimization not successful: (1.1405390676012483, 10.043276576723297, 0.29)
# Error during model generation for star with mass 1.1256729861646957, age 10.056486519198327, feh 0.29: EEP minimization not successful: (1.1256729861646957, 10.056486519198327, 0.29)
# Error during model generation for star with mass 1.42339314900181, age 10.053230322841966, feh 0.29: EEP minimization not successful: (1.42339314900181, 10.053230322841966, 0.29)
# Error during model generation for star with mass 1.9932566044045363, age 10.110746466590733, feh 0.29: EEP minimization not successful: (1.9932566044045363, 10.110746466590733, 0.29)
# Error during model generation for star with mass 1.061068103163868, age 10.087124872331103, feh 0.29: EEP minimization not successful: (1.061068103163868, 10.087124872331103, 0.29)
# Error during model generation for star with mass 1.3387972867769902, age 10.048682742030389, feh 0.29: EEP minimization not successful: (1.3387972867769902, 10.048682742030389, 0.29)
# Error during model generation for star with mass 1.2950747836248233, age 10.057399613202467, feh 0.29: EEP minimization not successful: (1.2950747836248233, 10.057399613202467, 0.29)
# Error during model generation for star with mass 1.1155561880803497, age 10.043993666320167, feh 0.29: EEP minimization not successful: (1.1155561880803497, 10.043993666320167, 0.29)
# Error during model generation for star with mass 1.1660752612666885, age 10.059293206357038, feh 0.29: EEP minimization not successful: (1.1660752612666885, 10.059293206357038, 0.29)
# Error during model generation for star with mass 1.623731529864806, age 10.087496481877015, feh 0.29: EEP minimization not successful: (1.623731529864806, 10.087496481877015, 0.29)
# Error during model generation for star with mass 1.0790507051746467, age 10.092052664675723, feh 0.29: EEP minimization not successful: (1.0790507051746467, 10.092052664675723, 0.29)
# Error during model generation for star with mass 1.129636196541644, age 10.061284112048112, feh 0.29: EEP minimization not successful: (1.129636196541644, 10.061284112048112, 0.29)
# Error during model generation for star with mass 1.3320925562434949, age 10.101599357148027, feh 0.29: EEP minimization not successful: (1.3320925562434949, 10.101599357148027, 0.29)
# Error during model generation for star with mass 1.5103750397750648, age 10.056566920798852, feh 0.29: EEP minimization not successful: (1.5103750397750648, 10.056566920798852, 0.29)
# Error during model generation for star with mass 1.2862418505604627, age 10.103461709892105, feh 0.29: EEP minimization not successful: (1.2862418505604627, 10.103461709892105, 0.29)
# Error during model generation for star with mass 1.2114851473312702, age 10.095257351371378, feh 0.29: EEP minimization not successful: (1.2114851473312702, 10.095257351371378, 0.29)
# Error during model generation for star with mass 2.0395629982699406, age 9.408023753085729, feh 0.29: EEP minimization not successful: (2.0395629982699406, 9.408023753085729, 0.29)
# Error during model generation for star with mass 1.3788933473470653, age 10.07963205425435, feh 0.29: EEP minimization not successful: (1.3788933473470653, 10.07963205425435, 0.29)
# Error during model generation for star with mass 1.1136802686923175, age 10.077978737273881, feh 0.29: EEP minimization not successful: (1.1136802686923175, 10.077978737273881, 0.29)
# Error during model generation for star with mass 1.5246492276854282, age 10.051256424446235, feh 0.29: EEP minimization not successful: (1.5246492276854282, 10.051256424446235, 0.29)
# Error during model generation for star with mass 2.0885256932652503, age 10.048982570282318, feh 0.29: EEP minimization not successful: (2.0885256932652503, 10.048982570282318, 0.29)
# Error during model generation for star with mass 1.2491096617347428, age 10.048499244685262, feh 0.29: EEP minimization not successful: (1.2491096617347428, 10.048499244685262, 0.29)
# Error during model generation for star with mass 1.0817232123397942, age 10.083138433579089, feh 0.29: EEP minimization not successful: (1.0817232123397942, 10.083138433579089, 0.29)
# Error during model generation for star with mass 1.1083280797734552, age 10.041530169739705, feh 0.29: EEP minimization not successful: (1.1083280797734552, 10.041530169739705, 0.29)
# Error during model generation for star with mass 1.1445031901330835, age 10.07501503332036, feh 0.29: EEP minimization not successful: (1.1445031901330835, 10.07501503332036, 0.29)
# Error during model generation for star with mass 1.0640648115372089, age 10.098059805149342, feh 0.29: EEP minimization not successful: (1.0640648115372089, 10.098059805149342, 0.29)
# Error during model generation for star with mass 1.2012467666337199, age 10.052094306749797, feh 0.29: EEP minimization not successful: (1.2012467666337199, 10.052094306749797, 0.29)
# Error during model generation for star with mass 1.2563024668465288, age 10.07578580076766, feh 0.29: EEP minimization not successful: (1.2563024668465288, 10.07578580076766, 0.29)
# Error during model generation for star with mass 1.1593700620343241, age 10.054948884656795, feh 0.29: EEP minimization not successful: (1.1593700620343241, 10.054948884656795, 0.29)
# Error during model generation for star with mass 1.1455507256323343, age 10.105763308844525, feh 0.29: EEP minimization not successful: (1.1455507256323343, 10.105763308844525, 0.29)
# Error during model generation for star with mass 1.1692808251010982, age 10.088604674920767, feh 0.29: EEP minimization not successful: (1.1692808251010982, 10.088604674920767, 0.29)
# Error during model generation for star with mass 1.1691440344273585, age 10.087898536160552, feh 0.29: EEP minimization not successful: (1.1691440344273585, 10.087898536160552, 0.29)
# Error during model generation for star with mass 1.8046758128121674, age 10.104312944069953, feh 0.29: EEP minimization not successful: (1.8046758128121674, 10.104312944069953, 0.29)
# Error during model generation for star with mass 1.5629529831504552, age 10.111286977751838, feh 0.29: EEP minimization not successful: (1.5629529831504552, 10.111286977751838, 0.29)
# Error during model generation for star with mass 1.2407228716843723, age 10.06287938081507, feh 0.29: EEP minimization not successful: (1.2407228716843723, 10.06287938081507, 0.29)
# Error during model generation for star with mass 1.096227345579257, age 10.06901996707467, feh 0.29: EEP minimization not successful: (1.096227345579257, 10.06901996707467, 0.29)
# Error during model generation for star with mass 1.0942011559018276, age 10.093343691526142, feh 0.29: EEP minimization not successful: (1.0942011559018276, 10.093343691526142, 0.29)
# Error during model generation for star with mass 1.1537295296851737, age 10.058421127306932, feh 0.29: EEP minimization not successful: (1.1537295296851737, 10.058421127306932, 0.29)
# Error during model generation for star with mass 1.3098596792852986, age 10.10903554381744, feh 0.29: EEP minimization not successful: (1.3098596792852986, 10.10903554381744, 0.29)
# Error during model generation for star with mass 1.0500995754999445, age 10.112484214800649, feh 0.29: EEP minimization not successful: (1.0500995754999445, 10.112484214800649, 0.29)
# Error during model generation for star with mass 1.0814085146134806, age 10.108021980837583, feh 0.29: EEP minimization not successful: (1.0814085146134806, 10.108021980837583, 0.29)
# Error during model generation for star with mass 1.2291855324782852, age 10.051260282413294, feh 0.29: EEP minimization not successful: (1.2291855324782852, 10.051260282413294, 0.29)
# Error during model generation for star with mass 1.1232601658682366, age 10.088734674685297, feh 0.29: EEP minimization not successful: (1.1232601658682366, 10.088734674685297, 0.29)
# Error during model generation for star with mass 1.2223514028703482, age 10.090546125282891, feh 0.29: EEP minimization not successful: (1.2223514028703482, 10.090546125282891, 0.29)
# Error during model generation for star with mass 1.2389747781718945, age 10.105359364114804, feh 0.29: EEP minimization not successful: (1.2389747781718945, 10.105359364114804, 0.29)
# Error during model generation for star with mass 1.205656126222709, age 10.11019833326927, feh 0.29: EEP minimization not successful: (1.205656126222709, 10.11019833326927, 0.29)
# Error during model generation for star with mass 1.0959371264893056, age 10.059488804553462, feh 0.29: EEP minimization not successful: (1.0959371264893056, 10.059488804553462, 0.29)
# Error during model generation for star with mass 2.5023149937403524, age 10.055312471043122, feh 0.29: EEP minimization not successful: (2.5023149937403524, 10.055312471043122, 0.29)
# Error during model generation for star with mass 1.0713584103549163, age 10.071671695953142, feh 0.29: EEP minimization not successful: (1.0713584103549163, 10.071671695953142, 0.29)
# Error during model generation for star with mass 2.9768740861969376, age 10.045730404855556, feh 0.29: EEP minimization not successful: (2.9768740861969376, 10.045730404855556, 0.29)
# ...
# Error during model generation for star with mass 1.0819325897066732, age 10.103300520907123, feh 0.29: EEP minimization not successful: (1.0819325897066732, 10.103300520907123, 0.29)
# Error during model generation for star with mass 1.1258343608652905, age 10.104501119581887, feh 0.29: EEP minimization not successful: (1.1258343608652905, 10.104501119581887, 0.29)
# Error during model generation for star with mass 2.0567486164490196, age 10.047786189368686, feh 0.29: EEP minimization not successful: (2.0567486164490196, 10.047786189368686, 0.29)
# Error during model generation for star with mass 1.1638281949921738, age 10.076297311247853, feh 0.29: EEP minimization not successful: (1.1638281949921738, 10.076297311247853, 0.29)
# Error during model generation for star with mass 1.0687437366135695, age 10.109850072682983, feh 0.29: EEP minimization not successful: (1.0687437366135695, 10.109850072682983, 0.29)
# Error during model generation for star with mass 1.0923857344827967, age 10.075088845887223, feh 0.29: EEP minimization not successful: (1.0923857344827967, 10.075088845887223, 0.29)
# Error during model generation for star with mass 1.2442666501997954, age 10.055563955178082, feh 0.29: EEP minimization not successful: (1.2442666501997954, 10.055563955178082, 0.29)
# Error during model generation for star with mass 1.1224444891053533, age 10.0807969375149, feh 0.29: EEP minimization not successful: (1.1224444891053533, 10.0807969375149, 0.29)
# Error during model generation for star with mass 1.1766099070750666, age 10.063217312234357, feh 0.29: EEP minimization not successful: (1.1766099070750666, 10.063217312234357, 0.29)
# Error during model generation for star with mass 1.1437605759381109, age 10.090145051905484, feh 0.29: EEP minimization not successful: (1.1437605759381109, 10.090145051905484, 0.29)
# Error during model generation for star with mass 1.0870356176831857, age 10.10192294827261, feh 0.29: EEP minimization not successful: (1.0870356176831857, 10.10192294827261, 0.29)
# Error during model generation for star with mass 1.0532597948380726, age 10.111098560304612, feh 0.29: EEP minimization not successful: (1.0532597948380726, 10.111098560304612, 0.29)
# Error during model generation for star with mass 1.3444325583526107, age 10.089129308147095, feh 0.29: EEP minimization not successful: (1.3444325583526107, 10.089129308147095, 0.29)
# Error during model generation for star with mass 1.4639403805409672, age 10.098284579068284, feh 0.29: EEP minimization not successful: (1.4639403805409672, 10.098284579068284, 0.29)
# Error during model generation for star with mass 1.253160641219159, age 10.0922214986548, feh 0.29: EEP minimization not successful: (1.253160641219159, 10.0922214986548, 0.29)
# Error during model generation for star with mass 1.248128732475652, age 10.075512803241617, feh 0.29: EEP minimization not successful: (1.248128732475652, 10.075512803241617, 0.29)
# Error during model generation for star with mass 1.053585924955956, age 10.101065138081944, feh 0.29: EEP minimization not successful: (1.053585924955956, 10.101065138081944, 0.29)
# Error during model generation for star with mass 1.257126041462383, age 10.058661438394122, feh 0.29: EEP minimization not successful: (1.257126041462383, 10.058661438394122, 0.29)
# Error during model generation for star with mass 1.0909438701392868, age 10.049939405918927, feh 0.29: EEP minimization not successful: (1.0909438701392868, 10.049939405918927, 0.29)
# Error during model generation for star with mass 1.090703398237712, age 10.057910596605524, feh 0.29: EEP minimization not successful: (1.090703398237712, 10.057910596605524, 0.29)
# Error during model generation for star with mass 1.290112611129746, age 10.088505726466927, feh 0.29: EEP minimization not successful: (1.290112611129746, 10.088505726466927, 0.29)
# Error during model generation for star with mass 1.536547838721162, age 10.081918817972882, feh 0.29: EEP minimization not successful: (1.536547838721162, 10.081918817972882, 0.29)
# Error during model generation for star with mass 1.6047536420071327, age 10.051679246751902, feh 0.29: EEP minimization not successful: (1.6047536420071327, 10.051679246751902, 0.29)
# Error during model generation for star with mass 1.1027222372252838, age 10.09222255333177, feh 0.29: EEP minimization not successful: (1.1027222372252838, 10.09222255333177, 0.29)
# Error during model generation for star with mass 1.0964074444164318, age 10.068325584633993, feh 0.29: EEP minimization not successful: (1.0964074444164318, 10.068325584633993, 0.29)
# Error during model generation for star with mass 1.3510461890814862, age 10.074451917461724, feh 0.29: EEP minimization not successful: (1.3510461890814862, 10.074451917461724, 0.29)
# Error during model generation for star with mass 1.1871870029855358, age 10.067152819809039, feh 0.29: EEP minimization not successful: (1.1871870029855358, 10.067152819809039, 0.29)
# Error during model generation for star with mass 1.1915995310869685, age 10.08447412913217, feh 0.29: EEP minimization not successful: (1.1915995310869685, 10.08447412913217, 0.29)
# Error during model generation for star with mass 1.4350754179095038, age 10.083055720762392, feh 0.29: EEP minimization not successful: (1.4350754179095038, 10.083055720762392, 0.29)
# Error during model generation for star with mass 1.2207946298120635, age 10.06292097797684, feh 0.29: EEP minimization not successful: (1.2207946298120635, 10.06292097797684, 0.29)
# Error during model generation for star with mass 1.1440551621694295, age 10.047037859564371, feh 0.29: EEP minimization not successful: (1.1440551621694295, 10.047037859564371, 0.29)
# Error during model generation for star with mass 1.7569315822584006, age 10.109566863792256, feh 0.29: EEP minimization not successful: (1.7569315822584006, 10.109566863792256, 0.29)
# Error during model generation for star with mass 1.7727956494184849, age 10.061984146309612, feh 0.29: EEP minimization not successful: (1.7727956494184849, 10.061984146309612, 0.29)
# Error during model generation for star with mass 1.2075875549838175, age 10.102126817487788, feh 0.29: EEP minimization not successful: (1.2075875549838175, 10.102126817487788, 0.29)
# Error during model generation for star with mass 1.1061883390847462, age 10.07734473960094, feh 0.29: EEP minimization not successful: (1.1061883390847462, 10.07734473960094, 0.29)
# Error during model generation for star with mass 1.203355961529419, age 10.076450971184236, feh 0.29: EEP minimization not successful: (1.203355961529419, 10.076450971184236, 0.29)
# Error during model generation for star with mass 1.249039937215547, age 10.11130141904709, feh 0.29: EEP minimization not successful: (1.249039937215547, 10.11130141904709, 0.29)
# Error during model generation for star with mass 1.0530953461028292, age 10.103419157411171, feh 0.29: EEP minimization not successful: (1.0530953461028292, 10.103419157411171, 0.29)
# Error during model generation for star with mass 1.165976441008066, age 10.047248906116724, feh 0.29: EEP minimization not successful: (1.165976441008066, 10.047248906116724, 0.29)
# Error during model generation for star with mass 1.451125027264044, age 10.05446725549244, feh 0.29: EEP minimization not successful: (1.451125027264044, 10.05446725549244, 0.29)
# Error during model generation for star with mass 1.2068046233090446, age 10.084817842427164, feh 0.29: EEP minimization not successful: (1.2068046233090446, 10.084817842427164, 0.29)
# Error during model generation for star with mass 1.4538176896213717, age 10.068760049193264, feh 0.29: EEP minimization not successful: (1.4538176896213717, 10.068760049193264, 0.29)
# Error during model generation for star with mass 1.5044106196055034, age 10.112138626233858, feh 0.29: EEP minimization not successful: (1.5044106196055034, 10.112138626233858, 0.29)
# Error during model generation for star with mass 1.0580947285762596, age 10.11077369375531, feh 0.29: EEP minimization not successful: (1.0580947285762596, 10.11077369375531, 0.29)
# Error during model generation for star with mass 1.1219899306999157, age 10.105813168016233, feh 0.29: EEP minimization not successful: (1.1219899306999157, 10.105813168016233, 0.29)
# Error during model generation for star with mass 1.0895031753754314, age 10.086944780165057, feh 0.29: EEP minimization not successful: (1.0895031753754314, 10.086944780165057, 0.29)
# Error during model generation for star with mass 1.0705211131728103, age 10.073615920023208, feh 0.29: EEP minimization not successful: (1.0705211131728103, 10.073615920023208, 0.29)
# Error during model generation for star with mass 1.3328495536636593, age 10.082039454458169, feh 0.29: EEP minimization not successful: (1.3328495536636593, 10.082039454458169, 0.29)
# Error during model generation for star with mass 1.2830864672030402, age 10.104234081035433, feh 0.29: EEP minimization not successful: (1.2830864672030402, 10.104234081035433, 0.29)
# Error during model generation for star with mass 1.4502225042813859, age 10.064020527194836, feh 0.29: EEP minimization not successful: (1.4502225042813859, 10.064020527194836, 0.29)
# Error during model generation for star with mass 1.674889943875551, age 10.10381945923006, feh 0.29: EEP minimization not successful: (1.674889943875551, 10.10381945923006, 0.29)
# Error during model generation for star with mass 1.1395013802913287, age 10.099344229792061, feh 0.29: EEP minimization not successful: (1.1395013802913287, 10.099344229792061, 0.29)
# Error during model generation for star with mass 1.3874239488821882, age 10.045669816961363, feh 0.29: EEP minimization not successful: (1.3874239488821882, 10.045669816961363, 0.29)
# Error during model generation for star with mass 1.212346834738432, age 10.072942233672997, feh 0.29: EEP minimization not successful: (1.212346834738432, 10.072942233672997, 0.29)
# Error during model generation for star with mass 1.800541899180356, age 10.051272620121551, feh 0.29: EEP minimization not successful: (1.800541899180356, 10.051272620121551, 0.29)
# Error during model generation for star with mass 1.1202267168519446, age 10.084363096758146, feh 0.29: EEP minimization not successful: (1.1202267168519446, 10.084363096758146, 0.29)
# Error during model generation for star with mass 1.10007585699697, age 10.060667743784363, feh 0.29: EEP minimization not successful: (1.10007585699697, 10.060667743784363, 0.29)
# Error during model generation for star with mass 1.1537948992733398, age 10.041621176811867, feh 0.29: EEP minimization not successful: (1.1537948992733398, 10.041621176811867, 0.29)
# Error during model generation for star with mass 1.105454300732999, age 10.081867235894771, feh 0.29: EEP minimization not successful: (1.105454300732999, 10.081867235894771, 0.29)
# Error during model generation for star with mass 1.1048234928078484, age 10.107278022453292, feh 0.29: EEP minimization not successful: (1.1048234928078484, 10.107278022453292, 0.29)
# Error during model generation for star with mass 1.6864335738924574, age 10.076740812558914, feh 0.29: EEP minimization not successful: (1.6864335738924574, 10.076740812558914, 0.29)
# Error during model generation for star with mass 1.5335092760997593, age 9.702679093909673, feh 0.29: EEP minimization not successful: (1.5335092760997593, 9.702679093909673, 0.29)
# Error during model generation for star with mass 1.5995263981460879, age 10.068792536539345, feh 0.29: EEP minimization not successful: (1.5995263981460879, 10.068792536539345, 0.29)
# Error during model generation for star with mass 1.3360012305744267, age 10.103564754647493, feh 0.29: EEP minimization not successful: (1.3360012305744267, 10.103564754647493, 0.29)
# Error during model generation for star with mass 1.082243504445216, age 10.059986767546093, feh 0.29: EEP minimization not successful: (1.082243504445216, 10.059986767546093, 0.29)
# Error during model generation for star with mass 1.2077939799721649, age 10.103788579923714, feh 0.29: EEP minimization not successful: (1.2077939799721649, 10.103788579923714, 0.29)
# Error during model generation for star with mass 1.150308095223682, age 10.048670235448501, feh 0.29: EEP minimization not successful: (1.150308095223682, 10.048670235448501, 0.29)
# Error during model generation for star with mass 1.0769925168167713, age 10.106736217198144, feh 0.29: EEP minimization not successful: (1.0769925168167713, 10.106736217198144, 0.29)
# Error during model generation for star with mass 1.434026892682125, age 10.11364136831135, feh 0.29: EEP minimization not successful: (1.434026892682125, 10.11364136831135, 0.29)
# Error during model generation for star with mass 1.0633032378453469, age 10.098907459914258, feh 0.29: EEP minimization not successful: (1.0633032378453469, 10.098907459914258, 0.29)
# Error during model generation for star with mass 1.7027956251900538, age 10.094623881832284, feh 0.29: EEP minimization not successful: (1.7027956251900538, 10.094623881832284, 0.29)
# Error during model generation for star with mass 1.256806296674655, age 10.097081350890615, feh 0.29: EEP minimization not successful: (1.256806296674655, 10.097081350890615, 0.29)
# Error during model generation for star with mass 1.0957917495136622, age 10.045490760721375, feh 0.29: EEP minimization not successful: (1.0957917495136622, 10.045490760721375, 0.29)
# Error during model generation for star with mass 1.1701367383323715, age 10.070304591758713, feh 0.29: EEP minimization not successful: (1.1701367383323715, 10.070304591758713, 0.29)
# Error during model generation for star with mass 1.1065533590781016, age 10.11099360201955, feh 0.29: EEP minimization not successful: (1.1065533590781016, 10.11099360201955, 0.29)
# Error during model generation for star with mass 1.069963401757799, age 10.09982571136485, feh 0.29: EEP minimization not successful: (1.069963401757799, 10.09982571136485, 0.29)
# Error during model generation for star with mass 1.2536773492091164, age 10.087896781926506, feh 0.29: EEP minimization not successful: (1.2536773492091164, 10.087896781926506, 0.29)
# Error during model generation for star with mass 1.4270001632783613, age 10.110521600809074, feh 0.29: EEP minimization not successful: (1.4270001632783613, 10.110521600809074, 0.29)
# Error during model generation for star with mass 1.4472800128540895, age 10.064194831340323, feh 0.29: EEP minimization not successful: (1.4472800128540895, 10.064194831340323, 0.29)
# Error during model generation for star with mass 1.0458108748143715, age 10.105922588394092, feh 0.29: EEP minimization not successful: (1.0458108748143715, 10.105922588394092, 0.29)
# Error during model generation for star with mass 1.4468293658283367, age 10.073316124539547, feh 0.29: EEP minimization not successful: (1.4468293658283367, 10.073316124539547, 0.29)
# Error during model generation for star with mass 1.2371454392844923, age 10.09319282985747, feh 0.29: EEP minimization not successful: (1.2371454392844923, 10.09319282985747, 0.29)
# Error during model generation for star with mass 1.1993954165447407, age 10.083570900029011, feh 0.29: EEP minimization not successful: (1.1993954165447407, 10.083570900029011, 0.29)
# Error during model generation for star with mass 1.272752238008852, age 10.088420852783118, feh 0.29: EEP minimization not successful: (1.272752238008852, 10.088420852783118, 0.29)
# Error during model generation for star with mass 1.132933098499034, age 10.075100938785033, feh 0.29: EEP minimization not successful: (1.132933098499034, 10.075100938785033, 0.29)
# Error during model generation for star with mass 1.1891005750367079, age 10.053401310902856, feh 0.29: EEP minimization not successful: (1.1891005750367079, 10.053401310902856, 0.29)
# Error during model generation for star with mass 1.8658276038977084, age 10.058752877084165, feh 0.29: EEP minimization not successful: (1.8658276038977084, 10.058752877084165, 0.29)

# %%
pmage_catalog_with_photometry.columns
# Out:
# <TableColumns names=('mass','age','flight_time','G','BP','RP','Teff','logg','radius','logL','feh','eep')>

# %%
pmage_catalog_with_photometry.write('/Users/mncavieres/Documents/2024-2/HVS/Data/SFH_sampling_catalogs/MIST_photometry/sample_NSC_with_photometry.fits', overwrite=True)

# %%
pmage_catalog_with_photometry = pmage_catalog_with_photometry.to_pandas().dropna()

# %%
plt.figure(figsize=(10, 6))
plt.hist(pmage_catalog_with_photometry['age'], bins=100, histtype='step', lw=2, color='k')
plt.show()

# %%
sns.histplot(data = pmage_catalog_with_photometry, x = 'mass', bins='scott', color='k')
plt.yscale('log')
plt.show()

# %%
plt.figure(figsize=( 6, 8))
#sns.scatterplot(data=pmage_catalog_with_photometry, x='Teff', y='G', hue='eep' , alpha=0.5)
plt.scatter(pmage_catalog_with_photometry['Teff'], pmage_catalog_with_photometry['G'],
             c=pmage_catalog_with_photometry['logg'], cmap='viridis', alpha=0.5, s = 2)
plt.colorbar(label='logg')
plt.xlim(7000, 3000)
plt.ylim(8, -5)
plt.xlabel('$T_{eff}$')
plt.ylabel('$M_G$')
plt.savefig(os.path.join(plots_path, 'Teff_vs_G_NSC.png'), dpi=300)

# %%
plt.figure(figsize=( 6, 8))
#sns.scatterplot(data=pmage_catalog_with_photometry, x='Teff', y='G', hue='eep' , alpha=0.5)
plt.scatter(pmage_catalog_with_photometry['Teff'], pmage_catalog_with_photometry['G'],
            c = 'k', alpha=0.5, s = 2)
plt.xlim(7000, 3000)
plt.ylim(8, -5)
plt.xlabel('$T_{eff}$')
plt.ylabel('$M_G$')
plt.savefig(os.path.join(plots_path, 'Teff_vs_G_NSC_nobar.png'), dpi=300)

# %%
plt.figure(figsize=( 6, 8))
#sns.scatterplot(data=pmage_catalog_with_photometry, x='Teff', y='G', hue='eep' , alpha=0.5)
plt.scatter(pmage_catalog_with_photometry['BP'] -pmage_catalog_with_photometry['RP'] , pmage_catalog_with_photometry['G'],
             c=pmage_catalog_with_photometry['logg'], cmap='spring', alpha=0.5, s = 2)
plt.colorbar(label='logg')
plt.xlim(0, 4)
plt.ylim(7, -3)
plt.xlabel('Teff')
plt.ylabel('G')
plt.savefig(os.path.join(plots_path, 'CMD_NSC.png'), dpi=300)

# %% [markdown]
# ## Turn into  training catalog

# %%
# merge with a large gaia catalog
data_gaia_big = pd.read_feather('/Users/mncavieres/Documents/2024-2/HVS/Data/Gaia_tests/200pc/raw_gaia_catalog/3M_sources_goodruwe.feather')
data_gaia_big['bp_rp'] = data_gaia_big['phot_bp_mean_mag'] - data_gaia_big['phot_rp_mean_mag']
data_gaia_big = data_gaia_big.dropna(subset=['bp_rp', 'phot_g_mean_mag'])

# subsample the gaia catalog
data_gaia = data_gaia_big.sample(50000)

# Add the path to the 'scripts' folder directly
sys.path.append('/Users/mncavieres/Documents/2024-2/HVS')

# %% [markdown]
# ### Run implied distance and $V_r$ calculations on Gaia data

# %%
# Now you can import from the 'scripts' package
from scripts.implied_d_vr import *  # Or import any other module
from scripts.selections import *

# %%
data_gaia_big = implied_calculations(data_gaia_big)

# %%
# keep only positive implied parallaxes
data_gaia_big = data_gaia_big.loc[data_gaia_big['implied_parallax'] > 0]

# %%
# add extinction correction
data_gaia_big = extinction_correction(data_gaia_big)

# %%
# compute the implied absolute magnitude
data_gaia_big['implied_M_g'] = data_gaia_big['phot_g_mean_mag'] - 5*np.log10(1000/data_gaia_big['implied_parallax']) + 5
data_gaia_big['implied_M_g_corr'] = data_gaia_big['phot_g_mean_mag'] - 5*np.log10(1000/data_gaia_big['implied_parallax']) + 5

# set all gaia stars as not hvs
data_gaia_big['is_hvs'] = 0

# %%
# now add the simulated cmd
# keep in mind that the simulated photometry should be called implied_M_g_corr and bp_rp_corr
simulated_catalog = Table()
simulated_catalog['bp_rp_corr'] = pmage_catalog_with_photometry['BP'] - pmage_catalog_with_photometry['RP']
simulated_catalog['implied_M_g_corr'] = pmage_catalog_with_photometry['G']
simulated_catalog['phot_g_mean_mag'] = pmage_catalog_with_photometry['G']
simulated_catalog['phot_bp_mean_mag'] = pmage_catalog_with_photometry['BP']
simulated_catalog['phot_rp_mean_mag'] = pmage_catalog_with_photometry['RP']
simulated_catalog['is_hvs'] = 1

# add some scatter in bp_rp_corr and implied_M_g_corr
simulated_catalog['bp_rp_corr'] += np.random.normal(0, 0.03, len(simulated_catalog))
simulated_catalog['implied_M_g_corr'] += np.random.normal(0, 0.003, len(simulated_catalog))

# %%
# plot the simulated cmd
plt.figure(figsize=( 6, 8))
plt.scatter(simulated_catalog['bp_rp_corr'], simulated_catalog['implied_M_g_corr'], c = simulated_catalog['is_hvs'], alpha=0.5, s = 2)
plt.xlim(0, 4)
plt.ylim(7, -3)
plt.xlabel('bp_rp')
plt.ylabel('M_g')
plt.show()

# %%
# create an astropy table with just the required columns from the gaia data
data_gaia_training = Table.from_pandas(data_gaia_big[['bp_rp', 'implied_M_g_corr', 'bp_rp_corr', 'phot_g_mean_mag', 'phot_bp_mean_mag', 'phot_rp_mean_mag', 'is_hvs']])

# %%
# merge the pandas dataframes
training_catalog = vstack([data_gaia_training, simulated_catalog])

# %%
training_catalog.write('/Users/mncavieres/Documents/2024-2/HVS/Data/SFH_sampling_catalogs/training_catalog_CMD_classification/NSC_training_catalog_smaller.fits', overwrite=True)

# %% [markdown]
# ## Test with simple populations

# %%
ages = np.linspace(0.1, 13, 1000)
mass = [1.0] * len(ages)
feh = [0.0] * len(ages)

# %%
get_star_photometry_v2
# Out:
# <function __main__.get_star_photometry_v2(feh_array, initial_mass_array, age_ejection_array, flight_time_array)>

# %%
testing_evol_track = get_star_photometry_v2(feh, mass, ages, [0]*len(ages))
# Out:
# Error during model generation for star with mass 1.0, age 10.079854554123724, feh 0.0: EEP minimization not successful: (1.0, 10.079854554123724, 0.0)
# Error during model generation for star with mass 1.0, age 10.080320913570734, feh 0.0: EEP minimization not successful: (1.0, 10.080320913570734, 0.0)
# Error during model generation for star with mass 1.0, age 10.080786772763043, feh 0.0: EEP minimization not successful: (1.0, 10.080786772763043, 0.0)
# Error during model generation for star with mass 1.0, age 10.081252132772729, feh 0.0: EEP minimization not successful: (1.0, 10.081252132772729, 0.0)
# Error during model generation for star with mass 1.0, age 10.081716994668424, feh 0.0: EEP minimization not successful: (1.0, 10.081716994668424, 0.0)
# Error during model generation for star with mass 1.0, age 10.082181359515337, feh 0.0: EEP minimization not successful: (1.0, 10.082181359515337, 0.0)
# Error during model generation for star with mass 1.0, age 10.082645228375261, feh 0.0: EEP minimization not successful: (1.0, 10.082645228375261, 0.0)
# Error during model generation for star with mass 1.0, age 10.08310860230659, feh 0.0: EEP minimization not successful: (1.0, 10.08310860230659, 0.0)
# Error during model generation for star with mass 1.0, age 10.083571482364334, feh 0.0: EEP minimization not successful: (1.0, 10.083571482364334, 0.0)
# Error during model generation for star with mass 1.0, age 10.084033869600134, feh 0.0: EEP minimization not successful: (1.0, 10.084033869600134, 0.0)
# Error during model generation for star with mass 1.0, age 10.084495765062277, feh 0.0: EEP minimization not successful: (1.0, 10.084495765062277, 0.0)
# Error during model generation for star with mass 1.0, age 10.084957169795706, feh 0.0: EEP minimization not successful: (1.0, 10.084957169795706, 0.0)
# Error during model generation for star with mass 1.0, age 10.085418084842036, feh 0.0: EEP minimization not successful: (1.0, 10.085418084842036, 0.0)
# Error during model generation for star with mass 1.0, age 10.085878511239576, feh 0.0: EEP minimization not successful: (1.0, 10.085878511239576, 0.0)
# Error during model generation for star with mass 1.0, age 10.086338450023327, feh 0.0: EEP minimization not successful: (1.0, 10.086338450023327, 0.0)
# Error during model generation for star with mass 1.0, age 10.086797902225012, feh 0.0: EEP minimization not successful: (1.0, 10.086797902225012, 0.0)
# Error during model generation for star with mass 1.0, age 10.08725686887308, feh 0.0: EEP minimization not successful: (1.0, 10.08725686887308, 0.0)
# Error during model generation for star with mass 1.0, age 10.087715350992722, feh 0.0: EEP minimization not successful: (1.0, 10.087715350992722, 0.0)
# Error during model generation for star with mass 1.0, age 10.08817334960589, feh 0.0: EEP minimization not successful: (1.0, 10.08817334960589, 0.0)
# Error during model generation for star with mass 1.0, age 10.0886308657313, feh 0.0: EEP minimization not successful: (1.0, 10.0886308657313, 0.0)
# Error during model generation for star with mass 1.0, age 10.089087900384456, feh 0.0: EEP minimization not successful: (1.0, 10.089087900384456, 0.0)
# Error during model generation for star with mass 1.0, age 10.08954445457766, feh 0.0: EEP minimization not successful: (1.0, 10.08954445457766, 0.0)
# Error during model generation for star with mass 1.0, age 10.090000529320019, feh 0.0: EEP minimization not successful: (1.0, 10.090000529320019, 0.0)
# Error during model generation for star with mass 1.0, age 10.090456125617473, feh 0.0: EEP minimization not successful: (1.0, 10.090456125617473, 0.0)
# Error during model generation for star with mass 1.0, age 10.090911244472792, feh 0.0: EEP minimization not successful: (1.0, 10.090911244472792, 0.0)
# Error during model generation for star with mass 1.0, age 10.091365886885601, feh 0.0: EEP minimization not successful: (1.0, 10.091365886885601, 0.0)
# Error during model generation for star with mass 1.0, age 10.091820053852386, feh 0.0: EEP minimization not successful: (1.0, 10.091820053852386, 0.0)
# Error during model generation for star with mass 1.0, age 10.09227374636651, feh 0.0: EEP minimization not successful: (1.0, 10.09227374636651, 0.0)
# Error during model generation for star with mass 1.0, age 10.092726965418231, feh 0.0: EEP minimization not successful: (1.0, 10.092726965418231, 0.0)
# Error during model generation for star with mass 1.0, age 10.093179711994706, feh 0.0: EEP minimization not successful: (1.0, 10.093179711994706, 0.0)
# Error during model generation for star with mass 1.0, age 10.093631987080006, feh 0.0: EEP minimization not successful: (1.0, 10.093631987080006, 0.0)
# Error during model generation for star with mass 1.0, age 10.094083791655136, feh 0.0: EEP minimization not successful: (1.0, 10.094083791655136, 0.0)
# Error during model generation for star with mass 1.0, age 10.094535126698036, feh 0.0: EEP minimization not successful: (1.0, 10.094535126698036, 0.0)
# Error during model generation for star with mass 1.0, age 10.094985993183606, feh 0.0: EEP minimization not successful: (1.0, 10.094985993183606, 0.0)
# Error during model generation for star with mass 1.0, age 10.095436392083712, feh 0.0: EEP minimization not successful: (1.0, 10.095436392083712, 0.0)
# Error during model generation for star with mass 1.0, age 10.095886324367196, feh 0.0: EEP minimization not successful: (1.0, 10.095886324367196, 0.0)
# Error during model generation for star with mass 1.0, age 10.096335790999895, feh 0.0: EEP minimization not successful: (1.0, 10.096335790999895, 0.0)
# Error during model generation for star with mass 1.0, age 10.09678479294465, feh 0.0: EEP minimization not successful: (1.0, 10.09678479294465, 0.0)
# Error during model generation for star with mass 1.0, age 10.097233331161316, feh 0.0: EEP minimization not successful: (1.0, 10.097233331161316, 0.0)
# Error during model generation for star with mass 1.0, age 10.097681406606782, feh 0.0: EEP minimization not successful: (1.0, 10.097681406606782, 0.0)
# Error during model generation for star with mass 1.0, age 10.098129020234973, feh 0.0: EEP minimization not successful: (1.0, 10.098129020234973, 0.0)
# Error during model generation for star with mass 1.0, age 10.098576172996873, feh 0.0: EEP minimization not successful: (1.0, 10.098576172996873, 0.0)
# Error during model generation for star with mass 1.0, age 10.099022865840526, feh 0.0: EEP minimization not successful: (1.0, 10.099022865840526, 0.0)
# Error during model generation for star with mass 1.0, age 10.099469099711058, feh 0.0: EEP minimization not successful: (1.0, 10.099469099711058, 0.0)
# Error during model generation for star with mass 1.0, age 10.099914875550681, feh 0.0: EEP minimization not successful: (1.0, 10.099914875550681, 0.0)
# Error during model generation for star with mass 1.0, age 10.100360194298712, feh 0.0: EEP minimization not successful: (1.0, 10.100360194298712, 0.0)
# Error during model generation for star with mass 1.0, age 10.10080505689158, feh 0.0: EEP minimization not successful: (1.0, 10.10080505689158, 0.0)
# Error during model generation for star with mass 1.0, age 10.10124946426284, feh 0.0: EEP minimization not successful: (1.0, 10.10124946426284, 0.0)
# Error during model generation for star with mass 1.0, age 10.101693417343181, feh 0.0: EEP minimization not successful: (1.0, 10.101693417343181, 0.0)
# Error during model generation for star with mass 1.0, age 10.102136917060447, feh 0.0: EEP minimization not successful: (1.0, 10.102136917060447, 0.0)
# Error during model generation for star with mass 1.0, age 10.102579964339636, feh 0.0: EEP minimization not successful: (1.0, 10.102579964339636, 0.0)
# Error during model generation for star with mass 1.0, age 10.10302256010292, feh 0.0: EEP minimization not successful: (1.0, 10.10302256010292, 0.0)
# Error during model generation for star with mass 1.0, age 10.103464705269655, feh 0.0: EEP minimization not successful: (1.0, 10.103464705269655, 0.0)
# Error during model generation for star with mass 1.0, age 10.103906400756394, feh 0.0: EEP minimization not successful: (1.0, 10.103906400756394, 0.0)
# Error during model generation for star with mass 1.0, age 10.104347647476892, feh 0.0: EEP minimization not successful: (1.0, 10.104347647476892, 0.0)
# Error during model generation for star with mass 1.0, age 10.104788446342125, feh 0.0: EEP minimization not successful: (1.0, 10.104788446342125, 0.0)
# Error during model generation for star with mass 1.0, age 10.105228798260296, feh 0.0: EEP minimization not successful: (1.0, 10.105228798260296, 0.0)
# Error during model generation for star with mass 1.0, age 10.10566870413685, feh 0.0: EEP minimization not successful: (1.0, 10.10566870413685, 0.0)
# Error during model generation for star with mass 1.0, age 10.106108164874483, feh 0.0: EEP minimization not successful: (1.0, 10.106108164874483, 0.0)
# Error during model generation for star with mass 1.0, age 10.10654718137315, feh 0.0: EEP minimization not successful: (1.0, 10.10654718137315, 0.0)
# Error during model generation for star with mass 1.0, age 10.106985754530085, feh 0.0: EEP minimization not successful: (1.0, 10.106985754530085, 0.0)
# Error during model generation for star with mass 1.0, age 10.107423885239804, feh 0.0: EEP minimization not successful: (1.0, 10.107423885239804, 0.0)
# Error during model generation for star with mass 1.0, age 10.107861574394116, feh 0.0: EEP minimization not successful: (1.0, 10.107861574394116, 0.0)
# Error during model generation for star with mass 1.0, age 10.10829882288214, feh 0.0: EEP minimization not successful: (1.0, 10.10829882288214, 0.0)
# Error during model generation for star with mass 1.0, age 10.108735631590314, feh 0.0: EEP minimization not successful: (1.0, 10.108735631590314, 0.0)
# Error during model generation for star with mass 1.0, age 10.109172001402396, feh 0.0: EEP minimization not successful: (1.0, 10.109172001402396, 0.0)
# Error during model generation for star with mass 1.0, age 10.10960793319949, feh 0.0: EEP minimization not successful: (1.0, 10.10960793319949, 0.0)
# Error during model generation for star with mass 1.0, age 10.110043427860047, feh 0.0: EEP minimization not successful: (1.0, 10.110043427860047, 0.0)
# Error during model generation for star with mass 1.0, age 10.110478486259877, feh 0.0: EEP minimization not successful: (1.0, 10.110478486259877, 0.0)
# Error during model generation for star with mass 1.0, age 10.110913109272165, feh 0.0: EEP minimization not successful: (1.0, 10.110913109272165, 0.0)
# Error during model generation for star with mass 1.0, age 10.11134729776747, feh 0.0: EEP minimization not successful: (1.0, 10.11134729776747, 0.0)
# Error during model generation for star with mass 1.0, age 10.111781052613747, feh 0.0: EEP minimization not successful: (1.0, 10.111781052613747, 0.0)
# Error during model generation for star with mass 1.0, age 10.112214374676352, feh 0.0: EEP minimization not successful: (1.0, 10.112214374676352, 0.0)
# Error during model generation for star with mass 1.0, age 10.112647264818056, feh 0.0: EEP minimization not successful: (1.0, 10.112647264818056, 0.0)
# Error during model generation for star with mass 1.0, age 10.113079723899048, feh 0.0: EEP minimization not successful: (1.0, 10.113079723899048, 0.0)
# Error during model generation for star with mass 1.0, age 10.113511752776953, feh 0.0: EEP minimization not successful: (1.0, 10.113511752776953, 0.0)
# Error during model generation for star with mass 1.0, age 10.113943352306837, feh 0.0: EEP minimization not successful: (1.0, 10.113943352306837, 0.0)

# %%
testing_evol_track = testing_evol_track.to_pandas().dropna()

# %%
sns.scatterplot(data=testing_evol_track, x='Teff', y='G', hue='eep' , alpha=0.5)
plt.xlim(7000, 3000)
plt.ylim(8, -5)
# Out:
# (8.0, -5.0)
